# %%
# Analysis of H-angle for Normalised Pressure < 12.5kPa
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


#Loading dataset
df = pd.read_csv('Train2.csv')
df1 = pd.read_csv('Test2.csv')

# Extract features (X) and target variable (y)
X = df[['H_angle_inv', 'Seat_distance']]  # Add more features as needed
y = df['Normalised_Pressure']

X1 = df1[['H_angle_inv', 'Seat_distance']]
y1 = df1['Normalised_Pressure']

# Creating polynomial features
for degree in range(1,6):
    print("Degree = ", degree)
    poly = PolynomialFeatures(degree=degree)
    X_train_poly = poly.fit_transform(X)
    X_test_poly = poly.transform(X1)

    poly_reg = LinearRegression()
    poly_reg.fit(X_train_poly, y)

   
    y_train_pred = poly_reg.predict(X_train_poly)
    y_test_pred = poly_reg.predict(X_test_poly)

    # Evaluating the model
    train_rmse = mean_squared_error(y, y_train_pred, squared=False)
    test_rmse = mean_squared_error(y1, y_test_pred, squared=False)

    # Print the coefficients and RMSE
    print("Coefficients:", poly_reg.coef_)
    print("Intercept:", poly_reg.intercept_)
    print("Training RMSE:", train_rmse)
    print("Test RMSE:", test_rmse)
    
#Using the model to predict error in H_angle_calculation
X_Normalised_Pressure = df['Normalised_Pressure']
l1 = list(X_Normalised_Pressure)
X_Seat_distance = df['Seat_distance']
l2 = list(X_Seat_distance)
Y_H_angle = df['H-angle']
l3 = list(Y_H_angle)
n = len(l3)
Y_pred_train = list()
for i in range (0,n):
    #coefficients obtained from regression
    a = 2.01086826e+02
    b = 2.15249831e-03
    c = -0.8702305695556705
    y = a/(l1[i]-b*l2[i]-c)
    Y_pred_train.append(y)
train_rmse_h_angle = mean_squared_error(l3, Y_pred_train, squared=False)
print("--------------------------------------------------------Result---------------------------------------------------------")
print("The root mean squared error in H-angle prediction when Normalised pressure and seat distance is known using our model:")
print(train_rmse_h_angle,"degrees")
# Out:
# Degree =  1
# Coefficients: [0.00000000e+00 2.01086826e+02 2.15249831e-03]
# Intercept: -0.8702305695556705
# Training RMSE: 0.07998640697722718
# Test RMSE: 0.19311067162050163
# Degree =  2
# Coefficients: [ 0.00000000e+00 -4.10491073e+03  1.74964321e-01  2.62015122e+05
#  -1.06194877e+01 -7.37658945e-04]
# Intercept: 14.667990561156273
# Training RMSE: 0.07620136783426845
# Test RMSE: 0.19009800033060273
# Degree =  3
# Coefficients: [ 8.87701756e-02  8.95824781e+04  4.23034529e+01  1.97829645e+03
#  -4.17969157e+03 -4.54628060e-01  3.16511227e+01  3.34456578e+04
#   3.50560801e+01  8.66321493e-04]
# Intercept: -935.3716818005378
# Training RMSE: 1.3800335287873626e-09
# Test RMSE: 0.2972261768041443
# Degree =  4
# Coefficients: [-7.43224154e-03  8.40308791e+01 -8.72086646e+01  1.27908690e+00
#   1.38082670e+03  2.59614228e+00  1.39840997e-02  1.34074245e+01
#  -4.53102213e+01 -3.20052960e-02  1.26783512e-04  2.03391469e-02
#  -5.27585940e+02  5.39400377e-01  1.27902358e-04]
# Intercept: 970.0417400621906
# Training RMSE: 1.2588064220357905e-10
# Test RMSE: 0.3816942155448636
# Degree =  5
# Coefficients: [-1.75769468e-04  7.13759079e-02  1.77388131e-01  1.19156265e-03
#   1.75945908e+00 -1.07913426e+00  1.47709232e-05  2.67990924e-02
#   2.88872329e+01  4.05599922e-02  1.60765247e-07  2.93410460e-04
#   2.82079555e-01 -9.47296262e-01 -5.43300824e-04  1.61499751e-09
#   2.66696774e-06  4.69660122e-04 -1.09373900e+01  1.12393160e-02
#   2.21741782e-06]
# Intercept: 216.46497659781483
# Training RMSE: 3.658320657878592e-12
# Test RMSE: 0.4196448687757911
# --------------------------------------------------------Result---------------------------------------------------------
# The root mean squared error in H-angle prediction when Normalised pressure and seat distance is known using our model:
# 4.8671701204130615 degrees
